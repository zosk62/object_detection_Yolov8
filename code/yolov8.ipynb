# %%
import glob
import os

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras import Model,Input

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import cv2
from PIL import Image

# %%
# %%writefile bird2.yaml
#
# path: C:\Users\user\Data_Ana_3\Sprint2
# train: C:\Users\user\Data_Ana_3\Sprint2\data_new2\bird\train\image
# val: C:\Users\user\Data_Ana_3\Sprint2\data_new2\bird\val\image
#
# nc: 1
#
# # Classes
# names: ['bird']
# Out:
# Overwriting bird2.yaml

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
results = model.train(
   data='bird2.yaml',
   imgsz=256,
   epochs=5,
   batch=8,
   name='yolov8sbird2.pt'
)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.4 🚀 Python-3.9.18 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
results = model.train(
   data='bird.yaml',
   imgsz=256,
   epochs=5,
   batch=8,
   name='yolov8sbird.pt'
)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.4 🚀 Python-3.9.18 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
# %%writefile drone2.yaml
#
# path: C:\Users\user\Data_Ana_3\Sprint2
# train: C:\Users\user\Data_Ana_3\Sprint2\data_new2\drone\train\images
# val: C:\Users\user\Data_Ana_3\Sprint2\data_new2\drone\val\images
#
# nc: 1
#
# # Classes
# names: ['drone']
# Out:
# Writing drone2.yaml

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
results = model.train(
   data='drone2.yaml',
   imgsz=256,
   epochs=5,
   batch=8,
   name='yolov8sdrone.pt'
)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.4 🚀 Python-3.9.18 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
# %%writefile bird5.yaml
#
# path: C:\Users\user\Data_Ana_3\Sprint2
#
# train:
#     - C:\Users\user\Data_Ana_3\Sprint2\data_new4\bird\train\image
#
#
# val:
#     - C:\Users\user\Data_Ana_3\Sprint2\data_new4\bird\val\image
#
#
# nc: 1
#
# # Classes
# names:
#   0: bird
# Out:
# Overwriting bird5.yaml

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
results = model.train(
   data='bird5.yaml',
   imgsz=256,
   epochs=5,
   batch=8,
   name='yolov8sbird4.pt'
)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.4 🚀 Python-3.9.18 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
# %%writefile dronebird4.yaml
#
# path: C:\Users\user\Data_Ana_3
#
# train:
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new4\drone\train\images
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new4\bird\train\image
#
# val:
#
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new4\drone\val\images
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new4\bird\val\image
#
# nc: 2
#
# # Classes
# names: ['drone', 'bird']
# Out:
# Overwriting dronebird4.yaml

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
results = model.train(
   data='dronebird4.yaml',
   imgsz=256,
   epochs=5,
   batch=8,
   name='yolov8sdronebird4.pt'
)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.4 🚀 Python-3.9.18 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
# %%writefile dronebird10.yaml
#
# path: C:\Users\user\Data_Ana_3\sprint2\SFA
#
# train:
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new5\train\images\drone
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new5\train\images\bird
#
# val:
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new5\val\images\drone
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new5\val\images\bird
#
#
# nc: 2
#
# # Classes
# names: ['drone', 'bird']
# Out:
# Writing dronebird10.yaml

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
results = model.train(
   data='dronebird10.yaml',
   imgsz=256,
   epochs=5,
   batch=8,
   name='yolov8sdronebird10.pt'
)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.4 🚀 Python-3.9.18 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
# model = YOLO('drone2.yaml', task='train').load('yolov8n.pt')

# %%
# from ultralytics import YOLO

# model = YOLO('drone2.yaml').load("yolo-Weights/yolov8n.pt")  # build from YAML and transfer weights
# results = model.train(data='coco.yaml', task='train', epochs=5, imgsz=640)

# %%
# from ultralytics import YOLO

# model = YOLO('drone2.yaml').load('yolov8n.pt')


# results = model.train(data='coco.yaml', epochs=5, imgsz=640)

# %%
#model = YOLO('drone2.yaml', task='detect').load('yolov8n.pt')

# %%
from xml.dom import minidom
import os
import glob

lut={}
lut["14111"] =0
lut["14131"] =1
lut["14141"] =2

def convert_coordinates(size, box):
  dw = 1.0/size[0]
  dh = 1.0/size[1]
  x = (box[0]+box[1])/2.0
  y = (box[2]+box[3])/2.0
  w = box[1]-box[0]
  h = box[3]-box[2]
  x = x*dw
  w = w*dw
  y = y*dh
  h = h*dh
  return (x,y,w,h)


def convert_xml2yolo( lut ):

  for fname in glob.glob(r"C:\Users\user\Downloads\archive (5)\cub_200_2011_xml\train_labels\Gray_Kingbird_0025_70152.xml"):
      
      xmldoc = minidom.parse(fname)
      
      fname_out = (fname[:-4]+'.txt')

      with open(fname_out, "w") as f:

          itemlist = xmldoc.getElementsByTagName('object')
          size = xmldoc.getElementsByTagName('size')[0]
          width = int((size.getElementsByTagName('width')[0]).firstChild.data)
          height = int((size.getElementsByTagName('height')[0]).firstChild.data)

          for item in itemlist:
              # get class label
              classid =  (item.getElementsByTagName('name')[0]).firstChild.data
              if classid in lut:
                  label_str = str(lut[classid])
              else:
                  label_str = "-1"
                  print ("warning: label '%s' not in look-up table" % classid)

              # get bbox coordinates
              xmin = ((item.getElementsByTagName('bndbox')[0]).getElementsByTagName('xmin')[0]).firstChild.data
              ymin = ((item.getElementsByTagName('bndbox')[0]).getElementsByTagName('ymin')[0]).firstChild.data
              xmax = ((item.getElementsByTagName('bndbox')[0]).getElementsByTagName('xmax')[0]).firstChild.data
              ymax = ((item.getElementsByTagName('bndbox')[0]).getElementsByTagName('ymax')[0]).firstChild.data
              b = (float(xmin), float(xmax), float(ymin), float(ymax))
              bb = convert_coordinates((width,height), b)
              #print(bb)

              f.write(label_str + " " + " ".join([("%.6f" % a) for a in bb]) + '\n')

      print ("wrote %s" % fname_out)



def main():
  convert_xml2yolo( lut )


if __name__ == '__main__':
  main()
# Out:
# ...
# wrote C:\Users\user\Downloads\archive (5)\cub_200_2011_xml\train_labels\Gray_Kingbird_0025_70152.txt

# %%
def convert_xml2yolo(lut):
    for fname in glob.glob(r"C:\Users\user\Downloads\archive (5)\cub_200_2011_xml\train_labels\Gray_Kingbird_0025_70152.xml"):
        xmldoc = minidom.parse(fname)
        fname_out = (fname[:-4] + '.txt')

        with open(fname_out, "w") as f:
            itemlist = xmldoc.getElementsByTagName('object')
            size = xmldoc.getElementsByTagName('size')[0]
            width = int((size.getElementsByTagName('width')[0]).firstChild.data)
            height = int((size.getElementsByTagName('height')[0]).firstChild.data)

            for item in itemlist:
                # get class label
                classid = (item.getElementsByTagName('name')[0]).firstChild.data
                label_str = str(lut.get(classid, "1"))  # Set label to "1" if class id not found in lookup table

                # get bbox coordinates
                xmin = ((item.getElementsByTagName('bndbox')[0]).getElementsByTagName('xmin')[0]).firstChild.data
                ymin = ((item.getElementsByTagName('bndbox')[0]).getElementsByTagName('ymin')[0]).firstChild.data
                xmax = ((item.getElementsByTagName('bndbox')[0]).getElementsByTagName('xmax')[0]).firstChild.data
                ymax = ((item.getElementsByTagName('bndbox')[0]).getElementsByTagName('ymax')[0]).firstChild.data
                b = (float(xmin), float(xmax), float(ymin), float(ymax))
                bb = convert_coordinates((width, height), b)

                f.write(label_str + " " + " ".join([("%.6f" % a) for a in bb]) + '\n')

        print("wrote %s" % fname_out)
def main():
  convert_xml2yolo( lut )


if __name__ == '__main__':
  main()
# Out:
# wrote C:\Users\user\Downloads\archive (5)\cub_200_2011_xml\train_labels\Gray_Kingbird_0025_70152.txt

# %%
from PIL import Image, ImageDraw
import glob

def draw_boxes(image_path, label_path):
    # Load the image
    image = Image.open(image_path)

    # Load bounding box information from the label file
    with open(label_path, 'r') as label_file:
        lines = label_file.readlines()

    # Draw bounding boxes on the image
    draw = ImageDraw.Draw(image)
    for line in lines:
        # Parse label information
        parts = line.strip().split()
        label = int(parts[0])
        x, y, w, h = map(float, parts[1:])
        
        # Convert relative coordinates to absolute coordinates
        width, height = image.size
        x_abs = int(x * width)
        y_abs = int(y * height)
        w_abs = int(w * width)
        h_abs = int(h * height)

        # Draw the bounding box
        draw.rectangle([x_abs - w_abs / 2, y_abs - h_abs / 2, x_abs + w_abs / 2, y_abs + h_abs / 2], outline="red", width=2)

    # Show the image with bounding boxes
    image.show()

# Example usage
image_folder = r"C:\Users\user\Downloads\archive (5)\img\Gray_Kingbird_0025_70152.jpg"
label_file = r"C:\Users\user\Downloads\archive (5)\img\Gray_Kingbird_0025_70152.txt"

draw_boxes(image_folder, label_file)

# %%
from xml.dom import minidom
import os
import glob

lut = {}
lut["14111"] = 0
lut["14131"] = 1
lut["14141"] = 2

def convert_coordinates(size, box):
    dw = 1.0 / size[0]
    dh = 1.0 / size[1]
    x = (box[0] + box[1]) / 2.0
    y = (box[2] + box[3]) / 2.0
    w = box[1] - box[0]
    h = box[3] - box[2]
    x = x * dw
    w = w * dw
    y = y * dh
    h = h * dh
    return x, y, w, h

def convert_xml2yolo(lut, xml_folder, output_folder):
    for xml_file in glob.glob(os.path.join(xml_folder, "*.xml")):
        xmldoc = minidom.parse(xml_file)
        output_file = os.path.join(output_folder, os.path.splitext(os.path.basename(xml_file))[0] + '.txt')

        with open(output_file, "w") as f:
            itemlist = xmldoc.getElementsByTagName('object')
            size = xmldoc.getElementsByTagName('size')[0]
            width = int(size.getElementsByTagName('width')[0].firstChild.data)
            height = int(size.getElementsByTagName('height')[0].firstChild.data)

            for item in itemlist:
                classid = item.getElementsByTagName('name')[0].firstChild.data
                label_str = str(lut.get(classid, "1"))

                xmin = float(item.getElementsByTagName('bndbox')[0].getElementsByTagName('xmin')[0].firstChild.data)
                ymin = float(item.getElementsByTagName('bndbox')[0].getElementsByTagName('ymin')[0].firstChild.data)
                xmax = float(item.getElementsByTagName('bndbox')[0].getElementsByTagName('xmax')[0].firstChild.data)
                ymax = float(item.getElementsByTagName('bndbox')[0].getElementsByTagName('ymax')[0].firstChild.data)

                bbox = convert_coordinates((width, height), (xmin, xmax, ymin, ymax))
                f.write(label_str + " " + " ".join([f"{a:.6f}" for a in bbox]) + '\n')

        print(f"Wrote {output_file}")

def main():
    xml_folder = r"C:\Users\user\Downloads\archive (5)\cub_200_2011_xml\train_labels"
    output_folder = r"C:\Users\user\Downloads\archive (5)\img\train_labels" 
    convert_xml2yolo(lut, xml_folder, output_folder)

if __name__ == '__main__':
    main()
# Out:
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0003_29094.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0004_795623.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0006_795595.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0007_795600.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0008_795599.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0009_29155.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0010_29199.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0014_795607.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0016_29217.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\train_labels\Acadian_Flycatcher_0017_795598.txt
# ...

# %%
from PIL import Image, ImageDraw
import os

def draw_boxes(image_folder, label_folder, output_folder):
    for image_file in os.listdir(image_folder):
        if image_file.endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(image_folder, image_file)
            label_file = os.path.join(label_folder, os.path.splitext(image_file)[0] + '.txt')

            # Load the image
            image = Image.open(image_path)

            # Load bounding box information from the label file
            with open(label_file, 'r') as label_file:
                lines = label_file.readlines()

            # Draw bounding boxes on the image
            draw = ImageDraw.Draw(image)
            for line in lines:
                # Parse label information
                parts = line.strip().split()
                label = int(parts[0])
                x, y, w, h = map(float, parts[1:])
                
                # Convert relative coordinates to absolute coordinates
                width, height = image.size
                x_abs = int(x * width)
                y_abs = int(y * height)
                w_abs = int(w * width)
                h_abs = int(h * height)

                # Draw the bounding box
                draw.rectangle([x_abs - w_abs / 2, y_abs - h_abs / 2, x_abs + w_abs / 2, y_abs + h_abs / 2], outline="red", width=2)

            # Save or show the image with bounding boxes
            output_path = os.path.join(output_folder, os.path.splitext(image_file)[0] + '_boxed.jpg')
            image.save(output_path)
            print(f"Processed: {output_path}")

# Example usage
image_folder = r"C:\Users\user\Downloads\archive (5)\img\train_images"
label_folder = r"C:\Users\user\Downloads\archive (5)\img\train_labels"
output_folder = r"C:\Users\user\Downloads\archive (5)\img0"  # Specify the desired output folder
draw_boxes(image_folder, label_folder, output_folder)
# Out:
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0003_29094_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0004_795623_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0006_795595_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0007_795600_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0008_795599_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0009_29155_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0010_29199_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0014_795607_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0016_29217_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img0\Acadian_Flycatcher_0017_795598_boxed.jpg
# ...

# %%
from xml.dom import minidom
import os
import glob

lut = {}
lut["14111"] = 0
lut["14131"] = 1
lut["14141"] = 2

def convert_coordinates(size, box):
    dw = 1.0 / size[0]
    dh = 1.0 / size[1]
    x = (box[0] + box[1]) / 2.0
    y = (box[2] + box[3]) / 2.0
    w = box[1] - box[0]
    h = box[3] - box[2]
    x = x * dw
    w = w * dw
    y = y * dh
    h = h * dh
    return x, y, w, h

def convert_xml2yolo(lut, xml_folder, output_folder):
    for xml_file in glob.glob(os.path.join(xml_folder, "*.xml")):
        xmldoc = minidom.parse(xml_file)
        output_file = os.path.join(output_folder, os.path.splitext(os.path.basename(xml_file))[0] + '.txt')

        with open(output_file, "w") as f:
            itemlist = xmldoc.getElementsByTagName('object')
            size = xmldoc.getElementsByTagName('size')[0]
            width = int(size.getElementsByTagName('width')[0].firstChild.data)
            height = int(size.getElementsByTagName('height')[0].firstChild.data)

            for item in itemlist:
                classid = item.getElementsByTagName('name')[0].firstChild.data
                label_str = str(lut.get(classid, "1"))

                xmin = float(item.getElementsByTagName('bndbox')[0].getElementsByTagName('xmin')[0].firstChild.data)
                ymin = float(item.getElementsByTagName('bndbox')[0].getElementsByTagName('ymin')[0].firstChild.data)
                xmax = float(item.getElementsByTagName('bndbox')[0].getElementsByTagName('xmax')[0].firstChild.data)
                ymax = float(item.getElementsByTagName('bndbox')[0].getElementsByTagName('ymax')[0].firstChild.data)

                bbox = convert_coordinates((width, height), (xmin, xmax, ymin, ymax))
                f.write(label_str + " " + " ".join([f"{a:.6f}" for a in bbox]) + '\n')

        print(f"Wrote {output_file}")

def main():
    xml_folder = r"C:\Users\user\Downloads\archive (5)\cub_200_2011_xml\valid_labels"
    output_folder = r"C:\Users\user\Downloads\archive (5)\img\valid_labels" 
    convert_xml2yolo(lut, xml_folder, output_folder)

if __name__ == '__main__':
    main()
# Out:
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0005_29157.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0012_795612.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0013_29232.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0015_795578.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0021_795594.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0022_29145.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0024_29173.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0030_795591.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0031_795582.txt
# Wrote C:\Users\user\Downloads\archive (5)\img\valid_labels\Acadian_Flycatcher_0034_795583.txt
# ...

# %%
from PIL import Image, ImageDraw
import os

def draw_boxes(image_folder, label_folder, output_folder):
    for image_file in os.listdir(image_folder):
        if image_file.endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(image_folder, image_file)
            label_file = os.path.join(label_folder, os.path.splitext(image_file)[0] + '.txt')

            # Load the image
            image = Image.open(image_path)

            # Load bounding box information from the label file
            with open(label_file, 'r') as label_file:
                lines = label_file.readlines()

            # Draw bounding boxes on the image
            draw = ImageDraw.Draw(image)
            for line in lines:
                # Parse label information
                parts = line.strip().split()
                label = int(parts[0])
                x, y, w, h = map(float, parts[1:])
                
                # Convert relative coordinates to absolute coordinates
                width, height = image.size
                x_abs = int(x * width)
                y_abs = int(y * height)
                w_abs = int(w * width)
                h_abs = int(h * height)

                # Draw the bounding box
                draw.rectangle([x_abs - w_abs / 2, y_abs - h_abs / 2, x_abs + w_abs / 2, y_abs + h_abs / 2], outline="red", width=2)

            # Save or show the image with bounding boxes
            output_path = os.path.join(output_folder, os.path.splitext(image_file)[0] + '_boxed.jpg')
            image.save(output_path)
            print(f"Processed: {output_path}")

# Example usage
image_folder = r"C:\Users\user\Downloads\archive (5)\img\valid_images"
label_folder = r"C:\Users\user\Downloads\archive (5)\img\valid_labels"
output_folder = r"C:\Users\user\Downloads\archive (5)\img1"  # Specify the desired output folder
draw_boxes(image_folder, label_folder, output_folder)
# Out:
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0005_29157_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0012_795612_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0013_29232_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0015_795578_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0021_795594_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0022_29145_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0024_29173_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0030_795591_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0031_795582_boxed.jpg
# Processed: C:\Users\user\Downloads\archive (5)\img1\Acadian_Flycatcher_0034_795583_boxed.jpg
# ...

# %%
# %%writefile birdnew.yaml
#
# path: C:\Users\user\Data_Ana_3\Sprint2
# train: C:\Users\user\Data_Ana_3\Sprint2\data_new6\train_images
# val: C:\Users\user\Data_Ana_3\Sprint2\data_new6\valid_images
#
# nc: 1
#
# # Classes
# names: ['bird']
# Out:
# Writing birdnew.yaml

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
results = model.train(
   data='birdnew.yaml',
   imgsz=256,
   epochs=5,
   batch=8,
   name='yolov8sbirdnew.pt'
)  # train the model

# %%
# %%writefile dronebird25.yaml
#
# path: C:\Users\user\Data_Ana_3\sprint2\SFA
#
# train:
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new7\train\images\drone
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new7\train\images\bird
#
# val:
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new7\val\images\drone
#   - C:\Users\user\Data_Ana_3\Sprint2\data_new7\val\images\bird
#
#
# nc: 2
#
# # Classes
# names: ['drone', 'bird']
# Out:
# Writing dronebird25.yaml

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
results = model.train(
   data='dronebird25.yaml',
   imgsz=256,
   epochs=70,
   batch=32,
   name='yolov8sdronebirdlight.pt'
)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.4 🚀 Python-3.9.18 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
from ultralytics import YOLO
model=YOLO('yolov8n.pt')
model.train(
   data='dronebird25.yaml', epochs=3
   
)  # train the model
# Out:
# Ultralytics YOLOv8.1.4 🚀 Python-3.9.18 torch-2.1.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
model = YOLO('C:/Users/user/Data_Ana_3/sprint2/SFA/runs/detect/train19/weights/best.pt')
# Perform tracking with the model
results = model.track(source="https://www.youtube.com/watch?v=MFS5oA--fBo", show=True)  # Tracking with default tracker

# %%
import cv2
from ultralytics import YOLO
import math
from pytube import YouTube

                                                                       
# yolo_model = YOLO("yolo-Weights/yolov8n.pt")
# yolo_model = YOLO('C:/Users/user/Data_Ana_3/Sprint2/runs/detect/yolov8sdrone.pt/weights/best.pt')
# yolo_model = YOLO('C:/Users/user/Data_Ana_3/Sprint2/runs/detect/yolov8sdronebird25.pt/weights/best.pt')
# yolo_model = YOLO('C:/Users/user/Data_Ana_3/Sprint2/runs/detect/train2/weights/best.pt')
yolo_model = YOLO('C:/Users/user/Data_Ana_3/Sprint2/Final_files/runs/detect/yolov8sdronebirdlight.pt/weights/best.pt')  # 70 times training
# yolo_model = YOLO('C:/Users/user/Data_Ana_3/Sprint2/runs/detect/yolov8sdronebird25.pt3/weights/best.pt')  # 35 times training other computer



# YOLOv8 classes
yolo_classes = yolo_model.names

# YouTube video URL
# video_url = "https://www.youtube.com/watch?v=PX9p7VES3bk"
# video_url = "https://www.youtube.com/watch?v=Hhp11I-vGHA" # drone
# video_url = "https://www.youtube.com/shorts/EohBaUH0Ycw" # bird
# video_url = "https://www.youtube.com/shorts/8A8bN-YgEpw" # bird
# video_url = "https://www.youtube.com/watch?v=a1wp1RnC7kk" 
# video_url = "https://www.youtube.com/watch?v=ZO5lV0gh5i4&t=91s"
# video_url = "https://www.youtube.com/watch?v=a1wp1RnC7kk&t=22s"
# video_url ="https://www.youtube.com/watch?v=a1wp1RnC7kk"
# video_url ="https://www.youtube.com/watch?v=Hhp11I-vGHA&t=23s"
video_url ="https://www.youtube.com/watch?v=Y1zhsObP49o"


# Extract video stream URL using pytube
yt = YouTube(video_url)
video_stream_url = yt.streams.filter(file_extension="mp4", res="720p").first().url

# Webcam configuration with the video stream URL
cap = cv2.VideoCapture(video_stream_url)

while True:
    # Capture frame from webcam
    success, img = cap.read()

    # Check if the frame is None
    if img is None:
        break

    # YOLOv8 detection on webcam frame
    results = yolo_model(img, stream=True)

    # Draw bounding boxes on webcam frame if confidence is more than 0.5
    for r in results:
        boxes = r.boxes
        for box in boxes:
            confidence = box.conf[0]
            if confidence > 0.5:
                x1, y1, x2, y2 = box.xyxy[0].int().tolist()
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

                # Display confidence score
                text = f"{yolo_classes[int(box.cls[0])]}: {confidence:.2f}"

                # Draw text near the bounding box with different color and thickness
                org_text = (x1, y1 - 10)  # Adjust the position of the text
                font = cv2.FONT_HERSHEY_SIMPLEX
                fontScale = 0.5  # Adjust the font size
                color = (255, 0, 0)  # Change BGR values for a different color (blue in this case)
                thickness = 2  # Increase thickness for a bolder font
                cv2.putText(img, text, org_text, font, fontScale, color, thickness)

    # Display frames
    cv2.imshow('YouTube Video', img)

    # Break the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 128x256 1 bird, 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 1 bird, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 1 bird, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 1 bird, 22.5ms
# Speed: 0.0ms preprocess, 22.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 1 bird, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 1 bird, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 1 bird, 20.7ms
# Speed: 1.0ms preprocess, 20.7ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 1 bird, 22.2ms
# ...

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
# model = YOLO("yolo-Weights/yolov8n.pt")
model = YOLO('C:/Users/user/Data_Ana_3/Sprint2/Final_files/runs/detect/yolov8sdronebirdlight.pt/weights/best.pt')  # 70 times training
# object classes
classNames = model.names

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 192x256 (no detections), 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
#
# 0: 192x256 (no detections), 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
#
# 0: 192x256 (no detections), 24.2ms
# Speed: 0.0ms preprocess, 24.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
#
# 0: 192x256 (no detections), 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
#
# 0: 192x256 (no detections), 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
#
# 0: 192x256 (no detections), 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
#
# 0: 192x256 (no detections), 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
#
# ...
